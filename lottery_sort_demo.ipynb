# %% [markdown]
# # 員工抽獎排序模擬
#
# 此 Notebook 用來展示透過樂透號碼逐步決定員工排序。
#
# 流程：
#
# 1 每位員工簽注 5 個樂透號碼
# 2 主持人第一次抽 5 個號碼
# 3 若有員工對中號碼 → 進入有序區
# 4 若有序區未滿 5 人 → 每輪加抽 1 個號碼
# 5 有序區滿 5 人 → 停止抽號
# 6 依規則排序

# %%
employees = ["AAA","BBB","CCC","DDD","EEE","FFF","GGG"]

unordered = employees.copy()
ordered = []

lottery_numbers = list(range(1,31))

drawn_numbers = []
